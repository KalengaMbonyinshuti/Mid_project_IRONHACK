# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
data=pd.read_excel('../data/creditcardmarketing.xlsx')
data
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# 3                         2                   No          High
# 4                         1                   No        Medium
# ...                     ...                  ...           ...
# 17995                     1                   No           Low
# 17996                     1                   No           Low
# 17997                     1                   No           Low
# 17998                     1                   No        Medium
# 17999                     2                   No        Medium
#
#        # Credit Cards Held  # Homes Owned  Household Size Own Your Home  \
# 0                        2              1               4            No
# 1                        2              2               5           Yes
# 2                        2              1               2           Yes
# 3                        1              1               4            No
# 4                        2              1               6           Yes
# ...                    ...            ...             ...           ...
# 17995                    1              1               5           Yes
# 17996                    3              1               3           Yes
# 17997                    2              1               4            No
# 17998                    4              2               2           Yes
# 17999                    2              1               3            No
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance  Q4 Balance
# 0              1160.75      1669.0       877.0      1095.0      1002.0
# 1               147.25        39.0       106.0        78.0       366.0
# 2               276.50       367.0       352.0       145.0       242.0
# 3              1219.00      1578.0      1760.0      1119.0       419.0
# 4              1211.00      2140.0      1357.0       982.0       365.0
# ...                ...         ...         ...         ...         ...
# 17995           167.50       136.0        65.0        71.0       398.0
# 17996           850.50       984.0       940.0       943.0       535.0
# 17997          1087.25       918.0       767.0      1170.0      1494.0
# 17998          1022.25       626.0       983.0       865.0      1615.0
# 17999          1056.00       265.0      1378.0      1978.0       603.0
#
# [18000 rows x 17 columns]

# %% [markdown]
# 1. Question=drop the column `q4_balance` from the database Limit your returned results to 10.

# %%
data.drop(columns='Q4 Balance', inplace=True)
data
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# 3                         2                   No          High
# 4                         1                   No        Medium
# ...                     ...                  ...           ...
# 17995                     1                   No           Low
# 17996                     1                   No           Low
# 17997                     1                   No           Low
# 17998                     1                   No        Medium
# 17999                     2                   No        Medium
#
#        # Credit Cards Held  # Homes Owned  Household Size Own Your Home  \
# 0                        2              1               4            No
# 1                        2              2               5           Yes
# 2                        2              1               2           Yes
# 3                        1              1               4            No
# 4                        2              1               6           Yes
# ...                    ...            ...             ...           ...
# 17995                    1              1               5           Yes
# 17996                    3              1               3           Yes
# 17997                    2              1               4            No
# 17998                    4              2               2           Yes
# 17999                    2              1               3            No
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance
# 0              1160.75      1669.0       877.0      1095.0
# 1               147.25        39.0       106.0        78.0
# 2               276.50       367.0       352.0       145.0
# 3              1219.00      1578.0      1760.0      1119.0
# 4              1211.00      2140.0      1357.0       982.0
# ...                ...         ...         ...         ...
# 17995           167.50       136.0        65.0        71.0
# 17996           850.50       984.0       940.0       943.0
# 17997          1087.25       918.0       767.0      1170.0
# 17998          1022.25       626.0       983.0       865.0
# 17999          1056.00       265.0      1378.0      1978.0
#
# [18000 rows x 16 columns]

# %% [markdown]
# 2.how many rows of data you have(shape)

# %%
data.shape
# Out:
# (18000, 16)

# %% [markdown]
# 3. Now we will try to find the unique values in some of the categorical columns:
#
#     - What are the unique values in the column `Offer_accepted`?
#     - What are the unique values in the column `Reward`?
#     - What are the unique values in the column `mailer_type`?
#     - What are the unique values in the column `credit_cards_held`?
#     - What are the unique values in the column `household_size`?

# %%
data.columns
# Out:
# Index(['Customer Number', 'Offer Accepted', 'Reward', 'Mailer Type',
#        'Income Level', '# Bank Accounts Open', 'Overdraft Protection',
#        'Credit Rating', '# Credit Cards Held', '# Homes Owned',
#        'Household Size', 'Own Your Home', 'Average Balance', 'Q1 Balance',
#        'Q2 Balance', 'Q3 Balance'],
#       dtype='object')

# %%
data['Offer Accepted'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['Reward'].unique()
# Out:
# array(['Air Miles', 'Cash Back', 'Points'], dtype=object)

# %%
data['Mailer Type'].unique()
# Out:
# array(['Letter', 'Postcard'], dtype=object)

# %%
data['# Credit Cards Held'].unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)

# %%
data['Household Size'].unique()
# Out:
# array([4, 5, 2, 6, 3, 1, 8, 9], dtype=int64)

# %% [markdown]
# 4. Arrange the data in a decreasing order by the `average_balance` of the house. Return only the `customer_number` of the top 10 customers with the highest `average_balances` in your data

# %%
average_sorted=data[['Customer Number','Average Balance']].sort_values(by='Average Balance', ascending=False)
average_sorted.head(10)
# Out:
#        Customer Number  Average Balance
# 2296              2297          3366.25
# 12635            12636          2948.50
# 8887              8888          2738.50
# 10576            10577          2609.50
# 14003            14004          2437.50
# 10475            10476          2430.00
# 2655              2656          2336.75
# 15259            15260          2320.50
# 15608            15609          2271.50
# 8777              8778          2073.25

# %% [markdown]
# 5. What is the average balance of all the customers in your data?

# %%
data['Average Balance'].mean()
# Out:
# 940.5155624165554

# %% [markdown]
# 6. In this exercise we will use  `group by` to check the properties of some of the categorical variables in our data. Note wherever `average_balance` is asked in the questions below, please take the average of the column `average_balance`:

# %% [markdown]
#  - What is the average balance of the customers grouped by `Income Level`? The returned result should have only two columns, income level and `Average balance` of the customers. Use an alias to change the name of the second column.
#     - What is the average balance of the customers grouped by `number_of_bank_accounts_open`? The returned result should have only two columns, `number_of_bank_accounts_open` and `Average balance` of the customers. Use an alias to change the name of the second column.
#     - What is the average number of credit cards held by customers for each of the credit card ratings? The returned result should have only two columns, rating and average number of credit cards held. Use an alias to change the name of the second column.
#     - Is there any correlation between the columns `credit_cards_held` and `number_of_bank_accounts_open`? You can analyse this by grouping the data by one of the variables and then aggregating the results of the other column. Visually check if there is a positive correlation or negative correlation or no correlation between the variables.
#     You might also have to check the number of customers in each category (ie number of credit cards held) to assess if that category is well represented in the dataset to include it in your analysis. For eg. If the category is under-represented as compared to other categories, ignore that category in this analysis

# %% [markdown]
# What is the average balance of the customers grouped by Income Level? The returned result should have only two columns, income level and Average balance of the customers. Use an alias to change the name of the second column.

# %%
# Group the data by income level and calculate the average balance for each group
grouped_Income_Level = data.groupby("Income Level")["Average Balance"].mean().reset_index()

# Rename the second column to Average_Balance
grouped_Income_Level = grouped_Income_Level.rename(columns={"Average Balance": "Average_Balance of the customers"})
grouped_Income_Level
# Out:
#   Income Level  Average_Balance of the customers
# 0         High                        942.574021
# 1          Low                        937.664983
# 2       Medium                        940.892940

# %% [markdown]
# What is the average balance of the customers grouped by number_of_bank_accounts_open? The returned result should have only two columns, number_of_bank_accounts_open and Average balance of the customers. Use an alias to change the name of the second column.

# %%
# Group the data by income level and calculate the average balance for each group
grouped_bank_accounts = data.groupby("# Bank Accounts Open")["Average Balance"].mean().reset_index()

# Rename the second column to Average_Balance
grouped_bank_accounts = grouped_bank_accounts.rename(columns={"Average Balance": "Average balance of the customers"})
grouped_bank_accounts
# Out:
#    # Bank Accounts Open  Average balance of the customers
# 0                     1                        941.533604
# 1                     2                        936.469491
# 2                     3                        948.284746

# %%
data.columns
# Out:
# Index(['Customer Number', 'Offer Accepted', 'Reward', 'Mailer Type',
#        'Income Level', '# Bank Accounts Open', 'Overdraft Protection',
#        'Credit Rating', '# Credit Cards Held', '# Homes Owned',
#        'Household Size', 'Own Your Home', 'Average Balance', 'Q1 Balance',
#        'Q2 Balance', 'Q3 Balance'],
#       dtype='object')

# %% [markdown]
# What is the average number of credit cards held by customers for each of the credit card ratings? The returned result should have only two columns, rating and average number of credit cards held. Use an alias to change the name of the second column.

# %%
# Group the data by income level and calculate the average balance for each group
grouped_bank_accounts = data.groupby("Credit Rating")["# Credit Cards Held"].mean().reset_index()

# Rename the second column to Average_Balance
grouped_bank_accounts = grouped_bank_accounts.rename(columns={"# Credit Cards Held": "average number of credit cards held", "Credit Rating": "Rating"})
grouped_bank_accounts
# Out:
#    Rating  average number of credit cards held
# 0    High                             1.895240
# 1     Low                             1.903811
# 2  Medium                             1.911587

# %% [markdown]
# Is there any correlation between the columns credit_cards_held and number_of_bank_accounts_open? You can analyse this by grouping the data by one of the variables and then aggregating the results of the other column. Visually check if there is a positive correlation or negative correlation or no correlation between the variables. You might also have to check the number of customers in each category (ie number of credit cards held) to assess if that category is well represented in the dataset to include it in your analysis. For eg. If the category is under-represented as

# %%
df_grouped = data.groupby('# Credit Cards Held').agg({'# Bank Accounts Open': 'count'})
df_grouped
# Out:
#                      # Bank Accounts Open
# # Credit Cards Held
# 1                                    6154
# 2                                    7944
# 3                                    3387
# 4                                     515

# %%
# Plot the aggregated data as a scatter plot
plt.scatter(df_grouped.index, df_grouped.values)
plt.xlabel("Number of Credit Cards Held")
plt.ylabel("Mean Number of Bank Accounts Open")
plt.show()

# Calculate the Pearson's correlation coefficient
correlation = data["# Credit Cards Held"].corr(data["# Bank Accounts Open"])
correlation
# Out:
# -0.0017281895537878515

# %% [markdown]
# There is very very very little correlation between the two.

# %% [markdown]
# 7. Your managers are only interested in the customers with the following properties:

# %% [markdown]
#  - Credit rating medium or high
#     - Credit cards held 2 or less
#     - Owns their own home
#     - Household size 3 or more
#
#     For the rest of the things, they are not too concerned. Write a simple query to find what are the options available for them? Can you filter the customers who accepted the offers here?

# %% [markdown]
# Credit rating medium or high
#
# Credit cards held 2 or less
#
# Owns their own home
#
# Household size 3 or more

# %%
data
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# 3                         2                   No          High
# 4                         1                   No        Medium
# ...                     ...                  ...           ...
# 17995                     1                   No           Low
# 17996                     1                   No           Low
# 17997                     1                   No           Low
# 17998                     1                   No        Medium
# 17999                     2                   No        Medium
#
#        # Credit Cards Held  # Homes Owned  Household Size Own Your Home  \
# 0                        2              1               4            No
# 1                        2              2               5           Yes
# 2                        2              1               2           Yes
# 3                        1              1               4            No
# 4                        2              1               6           Yes
# ...                    ...            ...             ...           ...
# 17995                    1              1               5           Yes
# 17996                    3              1               3           Yes
# 17997                    2              1               4            No
# 17998                    4              2               2           Yes
# 17999                    2              1               3            No
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance
# 0              1160.75      1669.0       877.0      1095.0
# 1               147.25        39.0       106.0        78.0
# 2               276.50       367.0       352.0       145.0
# 3              1219.00      1578.0      1760.0      1119.0
# 4              1211.00      2140.0      1357.0       982.0
# ...                ...         ...         ...         ...
# 17995           167.50       136.0        65.0        71.0
# 17996           850.50       984.0       940.0       943.0
# 17997          1087.25       918.0       767.0      1170.0
# 17998          1022.25       626.0       983.0       865.0
# 17999          1056.00       265.0      1378.0      1978.0
#
# [18000 rows x 16 columns]

# %%
data1=data[((data['Credit Rating']=='High')|(data['Credit Rating']=='Medium'))&(data['# Credit Cards Held']<=2)
     &(data['Household Size']>=3)&(data['Own Your Home']=="Yes")]
data1
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 1                    2             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# 16                  17             No     Points    Postcard          Low
# 17                  18             No  Air Miles    Postcard          Low
# 19                  20             No  Cash Back      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17983            17984             No  Cash Back      Letter       Medium
# 17985            17986             No     Points    Postcard       Medium
# 17986            17987             No     Points      Letter         High
# 17987            17988             No     Points      Letter         High
# 17990            17991             No  Air Miles      Letter       Medium
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 1                         1                   No        Medium
# 4                         1                   No        Medium
# 16                        2                   No        Medium
# 17                        2                   No          High
# 19                        1                   No          High
# ...                     ...                  ...           ...
# 17983                     1                   No          High
# 17985                     1                   No        Medium
# 17986                     1                   No          High
# 17987                     1                   No        Medium
# 17990                     1                   No          High
#
#        # Credit Cards Held  # Homes Owned  Household Size Own Your Home  \
# 1                        2              2               5           Yes
# 4                        2              1               6           Yes
# 16                       1              1               4           Yes
# 17                       2              1               4           Yes
# 19                       2              1               5           Yes
# ...                    ...            ...             ...           ...
# 17983                    1              1               4           Yes
# 17985                    1              1               5           Yes
# 17986                    2              1               3           Yes
# 17987                    1              1               5           Yes
# 17990                    1              1               3           Yes
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance
# 1               147.25        39.0       106.0        78.0
# 4              1211.00      2140.0      1357.0       982.0
# 16             1217.00       567.0      1161.0       966.0
# 17             1185.25       272.0      1523.0      2042.0
# 19             1086.75       764.0       997.0       921.0
# ...                ...         ...         ...         ...
# 17983           262.75       468.0       163.0       380.0
# 17985          1022.75      1391.0      1660.0       647.0
# 17986           943.25      1583.0      1001.0       818.0
# 17987           943.00      1845.0      1015.0       684.0
# 17990           335.75       447.0       378.0       274.0
#
# [4956 rows x 16 columns]

# %% [markdown]
# For the rest of the things, they are not too concerned. Write a simple query to find what are the options available for them? Can you filter the customers who accepted the offers here?

# %%
customer_accepted_off=data1[data1['Offer Accepted']=='Yes']
customer_accepted_off
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 112                113            Yes  Air Miles      Letter         High
# 131                132            Yes  Air Miles    Postcard         High
# 250                251            Yes  Air Miles      Letter         High
# 477                478            Yes  Air Miles    Postcard       Medium
# 605                606            Yes  Air Miles      Letter         High
# ...                ...            ...        ...         ...          ...
# 17841            17842            Yes  Air Miles    Postcard          Low
# 17903            17904            Yes     Points    Postcard          Low
# 17931            17932            Yes     Points      Letter       Medium
# 17942            17943            Yes  Air Miles    Postcard          Low
# 17971            17972            Yes  Cash Back    Postcard          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 112                       1                  Yes          High
# 131                       2                   No        Medium
# 250                       1                   No        Medium
# 477                       2                   No          High
# 605                       2                  Yes        Medium
# ...                     ...                  ...           ...
# 17841                     1                   No          High
# 17903                     2                   No        Medium
# 17931                     1                   No          High
# 17942                     1                   No        Medium
# 17971                     1                   No          High
#
#        # Credit Cards Held  # Homes Owned  Household Size Own Your Home  \
# 112                      2              1               5           Yes
# 131                      2              2               3           Yes
# 250                      1              1               5           Yes
# 477                      2              1               3           Yes
# 605                      1              1               4           Yes
# ...                    ...            ...             ...           ...
# 17841                    2              1               3           Yes
# 17903                    1              1               4           Yes
# 17931                    2              1               5           Yes
# 17942                    1              1               3           Yes
# 17971                    2              2               4           Yes
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance
# 112            1082.50      1890.0      1405.0       996.0
# 131             811.50       820.0       958.0       564.0
# 250            1047.75       438.0       762.0      1014.0
# 477            1054.75      1364.0      1360.0       446.0
# 605             175.75       389.0        16.0        94.0
# ...                ...         ...         ...         ...
# 17841           881.25       878.0       871.0       808.0
# 17903          1038.00       275.0       510.0      1493.0
# 17931          1539.00      1423.0      1864.0      1527.0
# 17942          1026.25       297.0      1672.0      1569.0
# 17971          1221.75      2118.0      1632.0      1029.0
#
# [169 rows x 16 columns]

# %% [markdown]
# 8. Your managers want to find out the list of customers whose average balance is less than the average balance of all the customers in the database. Write a query to show them the list of such customers. You might need to use a subquery for this problem.

# %%
customer_accepted_off[customer_accepted_off["Average Balance"] < customer_accepted_off["Average Balance"].mean()]
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 131                132            Yes  Air Miles    Postcard         High
# 605                606            Yes  Air Miles      Letter         High
# 1046              1047            Yes  Air Miles    Postcard       Medium
# 1286              1287            Yes  Air Miles    Postcard       Medium
# 1424              1425            Yes  Cash Back    Postcard       Medium
# ...                ...            ...        ...         ...          ...
# 16427            16428            Yes  Cash Back    Postcard       Medium
# 16543            16544            Yes  Air Miles      Letter         High
# 16974            16975            Yes  Air Miles    Postcard          Low
# 17448            17449            Yes  Air Miles    Postcard       Medium
# 17841            17842            Yes  Air Miles    Postcard          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 131                       2                   No        Medium
# 605                       2                  Yes        Medium
# 1046                      1                  Yes        Medium
# 1286                      2                   No        Medium
# 1424                      2                   No          High
# ...                     ...                  ...           ...
# 16427                     1                   No        Medium
# 16543                     1                   No        Medium
# 16974                     1                   No        Medium
# 17448                     1                   No        Medium
# 17841                     1                   No          High
#
#        # Credit Cards Held  # Homes Owned  Household Size Own Your Home  \
# 131                      2              2               3           Yes
# 605                      1              1               4           Yes
# 1046                     1              1               3           Yes
# 1286                     1              1               4           Yes
# 1424                     2              1               4           Yes
# ...                    ...            ...             ...           ...
# 16427                    2              1               3           Yes
# 16543                    2              2               3           Yes
# 16974                    2              1               6           Yes
# 17448                    1              1               5           Yes
# 17841                    2              1               3           Yes
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance
# 131             811.50       820.0       958.0       564.0
# 605             175.75       389.0        16.0        94.0
# 1046            808.00       925.0       829.0       894.0
# 1286            702.25       527.0       845.0       748.0
# 1424            195.50       487.0        87.0       159.0
# ...                ...         ...         ...         ...
# 16427           153.00        17.0       245.0       196.0
# 16543           839.00       777.0       871.0       972.0
# 16974           825.50       794.0       900.0       640.0
# 17448           791.75       864.0       952.0       573.0
# 17841           881.25       878.0       871.0       808.0
#
# [62 rows x 16 columns]

# %% [markdown]
# 9. Since this is something that the senior management is regularly interested in, create a view called `Customers__Balance_View1` of the same query.

# %%
def Customers__Balance_View1(df):
    sorted_df=df[((df['Credit Rating']=='High')|(df['Credit Rating']=='Medium'))&(df['# Credit Cards Held']<=2)
     &(df['Household Size']>=3)&(df['Own Your Home']=="Yes")]
    
    customer_accepted_off=sorted_df[sorted_df['Offer Accepted']=='Yes']
    
    Managers_average_all_columns=customer_accepted_off[customer_accepted_off["Average Balance"] < customer_accepted_off["Average Balance"].mean()]
    return Managers_average_all_columns

# %%
Customers__Balance_View1(data)
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 131                132            Yes  Air Miles    Postcard         High
# 605                606            Yes  Air Miles      Letter         High
# 1046              1047            Yes  Air Miles    Postcard       Medium
# 1286              1287            Yes  Air Miles    Postcard       Medium
# 1424              1425            Yes  Cash Back    Postcard       Medium
# ...                ...            ...        ...         ...          ...
# 16427            16428            Yes  Cash Back    Postcard       Medium
# 16543            16544            Yes  Air Miles      Letter         High
# 16974            16975            Yes  Air Miles    Postcard          Low
# 17448            17449            Yes  Air Miles    Postcard       Medium
# 17841            17842            Yes  Air Miles    Postcard          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 131                       2                   No        Medium
# 605                       2                  Yes        Medium
# 1046                      1                  Yes        Medium
# 1286                      2                   No        Medium
# 1424                      2                   No          High
# ...                     ...                  ...           ...
# 16427                     1                   No        Medium
# 16543                     1                   No        Medium
# 16974                     1                   No        Medium
# 17448                     1                   No        Medium
# 17841                     1                   No          High
#
#        # Credit Cards Held  # Homes Owned  Household Size Own Your Home  \
# 131                      2              2               3           Yes
# 605                      1              1               4           Yes
# 1046                     1              1               3           Yes
# 1286                     1              1               4           Yes
# 1424                     2              1               4           Yes
# ...                    ...            ...             ...           ...
# 16427                    2              1               3           Yes
# 16543                    2              2               3           Yes
# 16974                    2              1               6           Yes
# 17448                    1              1               5           Yes
# 17841                    2              1               3           Yes
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance
# 131             811.50       820.0       958.0       564.0
# 605             175.75       389.0        16.0        94.0
# 1046            808.00       925.0       829.0       894.0
# 1286            702.25       527.0       845.0       748.0
# 1424            195.50       487.0        87.0       159.0
# ...                ...         ...         ...         ...
# 16427           153.00        17.0       245.0       196.0
# 16543           839.00       777.0       871.0       972.0
# 16974           825.50       794.0       900.0       640.0
# 17448           791.75       864.0       952.0       573.0
# 17841           881.25       878.0       871.0       808.0
#
# [62 rows x 16 columns]

# %% [markdown]
# 10. What is the number of people who accepted the offer vs number of people who did not?

# %%
accepted_offer_number = len(data[data["Offer Accepted"]=='Yes'])
accepted_offer_number
# Out:
# 1023

# %%
accepted_offer_number = data[data["Offer Accepted"]=='Yes'].shape[0]
accepted_offer_number
# Out:
# 1023

# %%
Not_accepted_offer_number= len(data[data["Offer Accepted"]=='No'])
Not_accepted_offer_number
# Out:
# 16977

# %%
Total_offers=accepted_offer_number+Not_accepted_offer_number
Total_offers
# Out:
# 18000

# %%
data.shape
# Out:
# (18000, 16)

# %% [markdown]
# 11. Your managers are more interested in customers with a credit rating of high or medium. What is the difference in average balances of the customers with high credit card rating and low credit card rating?

# %%
sorted_data=data[['Customer Number', 'Credit Rating', 'Average Balance']]
sorted_data
# Out:
#        Customer Number Credit Rating  Average Balance
# 0                    1          High          1160.75
# 1                    2        Medium           147.25
# 2                    3        Medium           276.50
# 3                    4          High          1219.00
# 4                    5        Medium          1211.00
# ...                ...           ...              ...
# 17995            17996           Low           167.50
# 17996            17997           Low           850.50
# 17997            17998           Low          1087.25
# 17998            17999        Medium          1022.25
# 17999            18000        Medium          1056.00
#
# [18000 rows x 3 columns]

# %%
df_grouped = sorted_data.groupby('Credit Rating').agg({'Average Balance': 'sum'})
df_grouped.reset_index(inplace=True)

# %%
df_grouped
# Out:
#   Credit Rating  Average Balance
# 0          High       5726790.50
# 1           Low       5593146.75
# 2        Medium       5586770.50

# %%
diff_high_low=df_grouped[df_grouped['Credit Rating']=='High']['Average Balance'][0]-df_grouped[df_grouped['Credit Rating']=='Low']['Average Balance'][1]
diff_high_low
# Out:
# 133643.75

# %%
df_grouped['Average Balance'][0]-df_grouped['Average Balance'][1]
# Out:
# 133643.75

# %% [markdown]
# 12. In the database, which all types of communication (`mailer_type`) were used and with how many customers?

# %%
Data_Mailer=data[['Mailer Type', 'Customer Number']]
Data_Mailer
# Out:
#       Mailer Type  Customer Number
# 0          Letter                1
# 1          Letter                2
# 2        Postcard                3
# 3          Letter                4
# 4          Letter                5
# ...           ...              ...
# 17995      Letter            17996
# 17996      Letter            17997
# 17997      Letter            17998
# 17998      Letter            17999
# 17999      Letter            18000
#
# [18000 rows x 2 columns]

# %%
df_grouped_Mailer = Data_Mailer.groupby('Mailer Type').agg({'Customer Number': 'count'})
df_grouped_Mailer
# Out:
#              Customer Number
# Mailer Type
# Letter                  8853
# Postcard                9147

# %% [markdown]
# 13. Provide the details of the customer that is the 11th least `Q1_balance` in your database.

# %%
mean_value=data['Q1 Balance'].mean()
data['Q1 Balance'].fillna(value=mean_value, inplace=True)

# %%
data
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# 3                         2                   No          High
# 4                         1                   No        Medium
# ...                     ...                  ...           ...
# 17995                     1                   No           Low
# 17996                     1                   No           Low
# 17997                     1                   No           Low
# 17998                     1                   No        Medium
# 17999                     2                   No        Medium
#
#        # Credit Cards Held  # Homes Owned  Household Size Own Your Home  \
# 0                        2              1               4            No
# 1                        2              2               5           Yes
# 2                        2              1               2           Yes
# 3                        1              1               4            No
# 4                        2              1               6           Yes
# ...                    ...            ...             ...           ...
# 17995                    1              1               5           Yes
# 17996                    3              1               3           Yes
# 17997                    2              1               4            No
# 17998                    4              2               2           Yes
# 17999                    2              1               3            No
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance
# 0              1160.75      1669.0       877.0      1095.0
# 1               147.25        39.0       106.0        78.0
# 2               276.50       367.0       352.0       145.0
# 3              1219.00      1578.0      1760.0      1119.0
# 4              1211.00      2140.0      1357.0       982.0
# ...                ...         ...         ...         ...
# 17995           167.50       136.0        65.0        71.0
# 17996           850.50       984.0       940.0       943.0
# 17997          1087.25       918.0       767.0      1170.0
# 17998          1022.25       626.0       983.0       865.0
# 17999          1056.00       265.0      1378.0      1978.0
#
# [18000 rows x 16 columns]

# %%
data_sortedby_Q1=data.sort_values(by='Q1 Balance').reset_index(drop=True)
data_sortedby_Q1.head(11)
# Out:
#     Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0             10830             No  Cash Back    Postcard         High
# 1             14829             No     Points    Postcard       Medium
# 2             11247             No     Points    Postcard       Medium
# 3              5558             No  Air Miles      Letter          Low
# 4             17141             No     Points      Letter       Medium
# 5             16313             No     Points      Letter       Medium
# 6              7932             No  Air Miles      Letter       Medium
# 7             14748             No  Cash Back      Letter       Medium
# 8              4172             No  Cash Back    Postcard          Low
# 9             10235             No     Points      Letter          Low
# 10             5178             No  Cash Back    Postcard         High
#
#     # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                      1                   No           Low
# 1                      1                   No        Medium
# 2                      1                  Yes        Medium
# 3                      1                   No          High
# 4                      1                   No           Low
# 5                      1                  Yes           Low
# 6                      1                   No        Medium
# 7                      1                   No        Medium
# 8                      1                   No        Medium
# 9                      1                  Yes        Medium
# 10                     2                   No          High
#
#     # Credit Cards Held  # Homes Owned  Household Size Own Your Home  \
# 0                     1              1               4           Yes
# 1                     2              1               2           Yes
# 2                     3              1               3           Yes
# 3                     1              1               5           Yes
# 4                     2              1               4           Yes
# 5                     2              1               5            No
# 6                     2              2               2           Yes
# 7                     1              2               3            No
# 8                     1              1               3           Yes
# 9                     3              1               4            No
# 10                    1              1               5           Yes
#
#     Average Balance  Q1 Balance  Q2 Balance  Q3 Balance
# 0            174.25         0.0       465.0        23.0
# 1            166.00         0.0        32.0       499.0
# 2            207.25         0.0       425.0       135.0
# 3           1086.50         0.0      1621.0      1542.0
# 4            241.50         0.0       182.0       348.0
# 5           1008.50         1.0      1468.0       950.0
# 6            260.25         1.0       411.0       216.0
# 7           1155.00         1.0      1630.0      1593.0
# 8             79.50         1.0        38.0        83.0
# 9           1188.75         1.0      1409.0      2168.0
# 10           107.25         1.0       111.0        19.0

# %%
data_sortedby_Q1.loc[10]
# Out:
# Customer Number              5178
# Offer Accepted                 No
# Reward                  Cash Back
# Mailer Type              Postcard
# Income Level                 High
# # Bank Accounts Open            2
# Overdraft Protection           No
# Credit Rating                High
# # Credit Cards Held             1
# # Homes Owned                   1
# Household Size                  5
# Own Your Home                 Yes
# Average Balance            107.25
# Q1 Balance                    1.0
# Q2 Balance                  111.0
# Q3 Balance                   19.0
# Name: 10, dtype: object

# %%
pd.DataFrame(data_sortedby_Q1.iloc[10])
# Out:
#                              10
# Customer Number            5178
# Offer Accepted               No
# Reward                Cash Back
# Mailer Type            Postcard
# Income Level               High
# # Bank Accounts Open          2
# Overdraft Protection         No
# Credit Rating              High
# # Credit Cards Held           1
# # Homes Owned                 1
# Household Size                5
# Own Your Home               Yes
# Average Balance          107.25
# Q1 Balance                  1.0
# Q2 Balance                111.0
# Q3 Balance                 19.0

# %%
data.sort_values(by='Q1 Balance').tail(11)
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 17982            17983             No     Points      Letter       Medium
# 1793              1794             No  Air Miles    Postcard       Medium
# 4349              4350             No  Air Miles      Letter         High
# 8891              8892             No  Cash Back      Letter         High
# 14003            14004             No  Cash Back      Letter       Medium
# 10576            10577             No     Points      Letter       Medium
# 10475            10476             No  Air Miles      Letter       Medium
# 8887              8888             No  Cash Back      Letter       Medium
# 15259            15260             No  Air Miles      Letter       Medium
# 2296              2297             No  Air Miles      Letter         High
# 12635            12636             No  Air Miles      Letter         High
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 17982                     1                   No        Medium
# 1793                      1                  Yes        Medium
# 4349                      2                   No           Low
# 8891                      2                   No        Medium
# 14003                     1                   No        Medium
# 10576                     3                   No          High
# 10475                     1                  Yes          High
# 8887                      1                   No        Medium
# 15259                     1                   No          High
# 2296                      1                   No        Medium
# 12635                     1                   No          High
#
#        # Credit Cards Held  # Homes Owned  Household Size Own Your Home  \
# 17982                    3              1               5           Yes
# 1793                     1              1               4            No
# 4349                     2              3               3            No
# 8891                     1              1               5           Yes
# 14003                    1              1               1           Yes
# 10576                    1              1               2           Yes
# 10475                    1              1               4           Yes
# 8887                     2              1               2           Yes
# 15259                    2              1               3            No
# 2296                     2              2               2            No
# 12635                    3              2               4            No
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance
# 17982          1168.75      2197.0      1002.0       596.0
# 1793           1134.00      2198.0      1356.0       456.0
# 4349           1118.00      2200.0       987.0       410.0
# 8891            970.25      2200.0       869.0       616.0
# 14003          2437.50      2250.0      2134.0      2945.0
# 10576          2609.50      2310.0      3421.0      2802.0
# 10475          2430.00      2435.0      2234.0      2576.0
# 8887           2738.50      2453.0      3240.0      3016.0
# 15259          2320.50      2502.0      2445.0      2012.0
# 2296           3366.25      2509.0      2918.0      3823.0
# 12635          2948.50      3450.0      3214.0      2750.0

# %%
data.isna().sum()
# Out:
# Customer Number          0
# Offer Accepted           0
# Reward                   0
# Mailer Type              0
# Income Level             0
# # Bank Accounts Open     0
# Overdraft Protection     0
# Credit Rating            0
# # Credit Cards Held      0
# # Homes Owned            0
# Household Size           0
# Own Your Home            0
# Average Balance         24
# Q1 Balance               0
# Q2 Balance              24
# Q3 Balance              24
# dtype: int64

# %%
data['# Credit Cards Held'].unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)
